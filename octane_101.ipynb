# %% [markdown]
# [Reference]
# https://github.com/gustavovelascoh/octane-NIR
# * octane.xlsx - octane NIR dataset provided by CAMO Software.
# * gasoline.csv - gasoline NIR dataset exported from pls R package

# %%
import numpy as np
import pandas as pd

def import_dataset(ds_name='octane'):
    """
    ds_name: Name of the dataset ('octane', 'gasoline')
    Returns:
    wls: Numpy ndarray: List of wavelength
    xdata: Pandas DataFrame: Measurements
    ydata: Pandas Series: Octane numbers
    """

    if ds_name == 'octane':
        oct_df = pd.read_excel('octane.xlsx')
        wls = np.array([int(i) for i in oct_df.columns.values[2:]])
        xdata = oct_df.loc[:, '1100':]
        ydata = oct_df['Octane number']
    elif ds_name == 'gasoline':
        import re

        gas_df = pd.read_csv('gasoline.csv')
        reg = re.compile('([0-9]+)')
        wls = np.array([int(reg.findall(i)[0]) for i in gas_df.columns.values[1:]])
        xdata = gas_df.loc[:, 'NIR.900 nm':]
        ydata = gas_df['octane']
    else:
        exit('Invalid Dataset')

    return wls, xdata, ydata

# %%
dataset = 'gasoline'
#dataset = 'octane'
wls, xdata, ydata = import_dataset(dataset)

# %%
print(len(wls))
wls
# Out:
# 401
# array([ 900,  902,  904,  906,  908,  910,  912,  914,  916,  918,  920,
#         922,  924,  926,  928,  930,  932,  934,  936,  938,  940,  942,
#         944,  946,  948,  950,  952,  954,  956,  958,  960,  962,  964,
#         966,  968,  970,  972,  974,  976,  978,  980,  982,  984,  986,
#         988,  990,  992,  994,  996,  998, 1000, 1002, 1004, 1006, 1008,
#        1010, 1012, 1014, 1016, 1018, 1020, 1022, 1024, 1026, 1028, 1030,
#        1032, 1034, 1036, 1038, 1040, 1042, 1044, 1046, 1048, 1050, 1052,
#        1054, 1056, 1058, 1060, 1062, 1064, 1066, 1068, 1070, 1072, 1074,
#        1076, 1078, 1080, 1082, 1084, 1086, 1088, 1090, 1092, 1094, 1096,
#        1098, 1100, 1102, 1104, 1106, 1108, 1110, 1112, 1114, 1116, 1118,
#        1120, 1122, 1124, 1126, 1128, 1130, 1132, 1134, 1136, 1138, 1140,
#        1142, 1144, 1146, 1148, 1150, 1152, 1154, 1156, 1158, 1160, 1162,
#        1164, 1166, 1168, 1170, 1172, 1174, 1176, 1178, 1180, 1182, 1184,
#        1186, 1188, 1190, 1192, 1194, 1196, 1198, 1200, 1202, 1204, 1206,
#        1208, 1210, 1212, 1214, 1216, 1218, 1220, 1222, 1224, 1226, 1228,
#        1230, 1232, 1234, 1236, 1238, 1240, 1242, 1244, 1246, 1248, 1250,
#        1252, 1254, 1256, 1258, 1260, 1262, 1264, 1266, 1268, 1270, 1272,
#        1274, 1276, 1278, 1280, 1282, 1284, 1286, 1288, 1290, 1292, 1294,
#        1296, 1298, 1300, 1302, 1304, 1306, 1308, 1310, 1312, 1314, 1316,
#        1318, 1320, 1322, 1324, 1326, 1328, 1330, 1332, 1334, 1336, 1338,
#        1340, 1342, 1344, 1346, 1348, 1350, 1352, 1354, 1356, 1358, 1360,
#        1362, 1364, 1366, 1368, 1370, 1372, 1374, 1376, 1378, 1380, 1382,
#        1384, 1386, 1388, 1390, 1392, 1394, 1396, 1398, 1400, 1402, 1404,
#        1406, 1408, 1410, 1412, 1414, 1416, 1418, 1420, 1422, 1424, 1426,
#        1428, 1430, 1432, 1434, 1436, 1438, 1440, 1442, 1444, 1446, 1448,
#        1450, 1452, 1454, 1456, 1458, 1460, 1462, 1464, 1466, 1468, 1470,
#        1472, 1474, 1476, 1478, 1480, 1482, 1484, 1486, 1488, 1490, 1492,
#        1494, 1496, 1498, 1500, 1502, 1504, 1506, 1508, 1510, 1512, 1514,
#        1516, 1518, 1520, 1522, 1524, 1526, 1528, 1530, 1532, 1534, 1536,
#        1538, 1540, 1542, 1544, 1546, 1548, 1550, 1552, 1554, 1556, 1558,
#        1560, 1562, 1564, 1566, 1568, 1570, 1572, 1574, 1576, 1578, 1580,
#        1582, 1584, 1586, 1588, 1590, 1592, 1594, 1596, 1598, 1600, 1602,
#        1604, 1606, 1608, 1610, 1612, 1614, 1616, 1618, 1620, 1622, 1624,
#        1626, 1628, 1630, 1632, 1634, 1636, 1638, 1640, 1642, 1644, 1646,
#        1648, 1650, 1652, 1654, 1656, 1658, 1660, 1662, 1664, 1666, 1668,
#        1670, 1672, 1674, 1676, 1678, 1680, 1682, 1684, 1686, 1688, 1690,
#        1692, 1694, 1696, 1698, 1700])

# %%
import dataframe_image as dfi

print(xdata.shape)
dfi.export(xdata, 'octane_table_101.png', max_cols=10, max_rows=10,)
xdata
# Out:
# (60, 401)
#     NIR.900 nm  NIR.902 nm  NIR.904 nm  NIR.906 nm  NIR.908 nm  NIR.910 nm
# 1    -0.050193   -0.045903   -0.042187   -0.037177   -0.033348   -0.031207  \
# 2    -0.044227   -0.039602   -0.035673   -0.030911   -0.026675   -0.023871
# 3    -0.046867   -0.041260   -0.036979   -0.031458   -0.026520   -0.023346
# 4    -0.046705   -0.042240   -0.038561   -0.034513   -0.030206   -0.027680
# 5    -0.050859   -0.045145   -0.041025   -0.036357   -0.032747   -0.031498
# 6    -0.048094   -0.042739   -0.038812   -0.034017   -0.030143   -0.027690
# 7    -0.049906   -0.044558   -0.040543   -0.035716   -0.031844   -0.029581
# 8    -0.049293   -0.043788   -0.039429   -0.034193   -0.029588   -0.026455
# 9    -0.049885   -0.044279   -0.040158   -0.034954   -0.031114   -0.028390
# 10   -0.051054   -0.045678   -0.041673   -0.036761   -0.033078   -0.030466
# 11   -0.052705   -0.047674   -0.043960   -0.039335   -0.035622   -0.033849
# 12   -0.050383   -0.044934   -0.041391   -0.036162   -0.032389   -0.030479
# 13   -0.047866   -0.043572   -0.039234   -0.033831   -0.029675   -0.026899
# 14   -0.046594   -0.041111   -0.036881   -0.031122   -0.026667   -0.023717
# 15   -0.042470   -0.036621   -0.032430   -0.026807   -0.021276   -0.018356
# 16   -0.048503   -0.043850   -0.040052   -0.035608   -0.031709   -0.029417
# 17   -0.052011   -0.046438   -0.042741   -0.037767   -0.033675   -0.031435
# 18   -0.055093   -0.049515   -0.045637   -0.040658   -0.036019   -0.033858
# 19   -0.055002   -0.049353   -0.045749   -0.040881   -0.036641   -0.034485
# 20   -0.053971   -0.048498   -0.044546   -0.039737   -0.035025   -0.032028
# 21   -0.056393   -0.051917   -0.048119   -0.042835   -0.038890   -0.037075
# 22   -0.041806   -0.037138   -0.033330   -0.028394   -0.024088   -0.022220
# 23   -0.056295   -0.050792   -0.047015   -0.041668   -0.037211   -0.035112
# 24   -0.056614   -0.050934   -0.047065   -0.042162   -0.037512   -0.035385
# 25   -0.056634   -0.050985   -0.047449   -0.042544   -0.037751   -0.035638
# 26   -0.053835   -0.048211   -0.043901   -0.039466   -0.034951   -0.032682
# 27   -0.054568   -0.049352   -0.045221   -0.040954   -0.036456   -0.034173
# 28   -0.056343   -0.050790   -0.046753   -0.042718   -0.038384   -0.036067
# 29   -0.055746   -0.050452   -0.046133   -0.042041   -0.037684   -0.035340
# 30   -0.056285   -0.051229   -0.047233   -0.043306   -0.038566   -0.036586
# 31   -0.055856   -0.050983   -0.047003   -0.042624   -0.038003   -0.035975
# 32   -0.054979   -0.049543   -0.045299   -0.041173   -0.036667   -0.034132
# 33   -0.056744   -0.051640   -0.047625   -0.043418   -0.038720   -0.036322
# 34   -0.055116   -0.049883   -0.045198   -0.041241   -0.036557   -0.034154
# 35   -0.055431   -0.049610   -0.046254   -0.041308   -0.037308   -0.034262
# 36   -0.054786   -0.049772   -0.045728   -0.041781   -0.037103   -0.034873
# 37   -0.052696   -0.047364   -0.043219   -0.039882   -0.035381   -0.032813
# 38   -0.051488   -0.045710   -0.041979   -0.037985   -0.034024   -0.030727
# 39   -0.050822   -0.045340   -0.040816   -0.036766   -0.031458   -0.029078
# 40   -0.053711   -0.047820   -0.043375   -0.039730   -0.035277   -0.032090
# 41   -0.052652   -0.046447   -0.043614   -0.040247   -0.035748   -0.033943
# 42   -0.050152   -0.044052   -0.040550   -0.036536   -0.032156   -0.030090
# 43   -0.045382   -0.040226   -0.036527   -0.032673   -0.028697   -0.026225
# 44   -0.050142   -0.044155   -0.040605   -0.036775   -0.032357   -0.029566
# 45   -0.055431   -0.049375   -0.046190   -0.042031   -0.037362   -0.035388
# 46   -0.062839   -0.056232   -0.053075   -0.048133   -0.044493   -0.041588
# 47   -0.060146   -0.054662   -0.051013   -0.046707   -0.042162   -0.040352
# 48   -0.059905   -0.053893   -0.049825   -0.045788   -0.039896   -0.037613
# 49   -0.060446   -0.054912   -0.051417   -0.046888   -0.042582   -0.040267
# 50   -0.060961   -0.056118   -0.052393   -0.048156   -0.043868   -0.041965
# 51   -0.052634   -0.046971   -0.043205   -0.039538   -0.034724   -0.032414
# 52   -0.052700   -0.047331   -0.043577   -0.040344   -0.035613   -0.033652
# 53   -0.053394   -0.047990   -0.044082   -0.040690   -0.036469   -0.033663
# 54   -0.054134   -0.048487   -0.045171   -0.041012   -0.035553   -0.034104
# 55   -0.049623   -0.044263   -0.041154   -0.037335   -0.032926   -0.030602
# 56   -0.046884   -0.042360   -0.038683   -0.035291   -0.030175   -0.027898
# 57   -0.055555   -0.049867   -0.045942   -0.042266   -0.037195   -0.034837
# 58   -0.053693   -0.048020   -0.044677   -0.041021   -0.036254   -0.034531
# 59   -0.056311   -0.051231   -0.047483   -0.044605   -0.039404   -0.037526
# 60   -0.058805   -0.053311   -0.049543   -0.045053   -0.040598   -0.038965
#
#     NIR.912 nm  NIR.914 nm  NIR.916 nm  NIR.918 nm  ...  NIR.1682 nm
# 1    -0.030036   -0.031298   -0.034217   -0.036012  ...     1.198461  \
# 2    -0.022571   -0.025410   -0.028960   -0.032740  ...     1.128877
# 3    -0.021392   -0.024993   -0.029309   -0.033920  ...     1.147964
# 4    -0.026042   -0.028280   -0.030920   -0.034012  ...     1.160089
# 5    -0.031415   -0.034611   -0.037781   -0.040752  ...     1.252712
# 6    -0.026387   -0.028811   -0.031481   -0.034124  ...     1.214046
# 7    -0.027915   -0.030292   -0.033590   -0.037184  ...     1.234174
# 8    -0.025104   -0.028102   -0.031801   -0.036157  ...     1.187996
# 9    -0.027017   -0.029609   -0.032937   -0.036862  ...     1.219162
# 10   -0.029295   -0.031736   -0.034843   -0.038419  ...     1.227318
# 11   -0.032669   -0.035076   -0.037459   -0.040534  ...     1.251647
# 12   -0.028614   -0.031738   -0.034432   -0.036488  ...     1.236618
# 13   -0.025460   -0.028133   -0.031637   -0.035215  ...     1.199439
# 14   -0.021758   -0.024917   -0.029152   -0.033473  ...     1.150171
# 15   -0.016116   -0.019680   -0.024589   -0.029472  ...     1.107501
# 16   -0.027995   -0.030589   -0.032894   -0.035546  ...     1.231412
# 17   -0.030016   -0.032774   -0.035619   -0.039340  ...     1.221685
# 18   -0.032356   -0.035238   -0.038240   -0.042084  ...     1.208462
# 19   -0.032852   -0.035723   -0.038415   -0.041081  ...     1.185953
# 20   -0.030581   -0.032772   -0.036772   -0.040725  ...     1.189496
# 21   -0.035381   -0.038580   -0.041193   -0.044240  ...     1.209946
# 22   -0.020429   -0.023380   -0.026519   -0.029953  ...     1.214297
# 23   -0.033790   -0.036529   -0.039416   -0.043021  ...     1.203184
# 24   -0.033810   -0.036981   -0.039910   -0.043189  ...     1.211848
# 25   -0.034164   -0.037250   -0.040238   -0.043446  ...     1.214928
# 26   -0.031312   -0.033782   -0.037050   -0.040557  ...     1.222141
# 27   -0.033066   -0.035521   -0.038449   -0.041375  ...     1.203253
# 28   -0.034715   -0.037117   -0.040004   -0.042628  ...     1.215054
# 29   -0.034286   -0.036270   -0.039331   -0.042332  ...     1.207200
# 30   -0.035222   -0.037604   -0.040532   -0.043434  ...     1.229997
# 31   -0.034708   -0.036853   -0.039795   -0.042890  ...     1.222627
# 32   -0.033121   -0.035130   -0.037817   -0.040240  ...     1.187338
# 33   -0.035358   -0.037381   -0.040105   -0.042422  ...     1.186506
# 34   -0.033351   -0.035328   -0.038093   -0.040302  ...     1.186216
# 35   -0.034115   -0.035523   -0.038780   -0.040580  ...     1.197016
# 36   -0.032462   -0.035916   -0.038543   -0.043005  ...     1.208933
# 37   -0.031885   -0.034334   -0.037243   -0.038527  ...     1.218744
# 38   -0.029478   -0.031468   -0.036109   -0.038571  ...     1.228883
# 39   -0.027847   -0.029164   -0.034641   -0.037432  ...     1.191156
# 40   -0.031238   -0.033153   -0.037076   -0.040173  ...     1.212733
# 41   -0.031325   -0.035319   -0.037886   -0.040906  ...     1.276561
# 42   -0.028906   -0.031714   -0.034768   -0.037636  ...     1.237985
# 43   -0.024899   -0.026252   -0.031305   -0.033514  ...     1.224900
# 44   -0.028514   -0.029725   -0.033475   -0.035601  ...     1.196784
# 45   -0.033041   -0.036786   -0.039450   -0.042702  ...     1.223531
# 46   -0.040467   -0.043202   -0.046477   -0.049311  ...     1.218801
# 47   -0.038058   -0.041425   -0.044844   -0.047471  ...     1.227396
# 48   -0.035854   -0.039694   -0.043639   -0.046829  ...     1.197319
# 49   -0.038564   -0.041482   -0.045056   -0.047595  ...     1.223806
# 50   -0.040130   -0.043010   -0.046227   -0.048838  ...     1.224987
# 51   -0.029820   -0.033670   -0.036481   -0.040107  ...     1.205736
# 52   -0.031383   -0.034717   -0.037500   -0.040242  ...     1.231920
# 53   -0.031475   -0.034740   -0.037418   -0.040692  ...     1.201475
# 54   -0.031523   -0.034866   -0.037200   -0.038979  ...     1.170220
# 55   -0.028713   -0.032058   -0.034363   -0.035440  ...     1.182659
# 56   -0.026519   -0.029413   -0.032182   -0.034033  ...     1.206536
# 57   -0.031842   -0.036051   -0.038897   -0.042842  ...     1.167444
# 58   -0.032428   -0.035264   -0.038362   -0.040816  ...     1.217198
# 59   -0.034336   -0.037852   -0.041023   -0.044488  ...     1.247442
# 60   -0.036749   -0.040284   -0.042080   -0.045058  ...     1.211312
#
#     NIR.1684 nm  NIR.1686 nm  NIR.1688 nm  NIR.1690 nm  NIR.1692 nm
# 1      1.224243     1.242645     1.250789     1.246626     1.250985  \
# 2      1.148342     1.189116     1.223242     1.253306     1.282889
# 3      1.167798     1.198287     1.237383     1.260979     1.276677
# 4      1.169350     1.201066     1.233299     1.262966     1.272709
# 5      1.238013     1.259616     1.273713     1.296524     1.299507
# 6      1.210217     1.241090     1.262138     1.288401     1.291118
# 7      1.226153     1.245143     1.265648     1.274731     1.292441
# 8      1.192901     1.222581     1.245782     1.260020     1.290305
# 9      1.214365     1.234969     1.251559     1.272416     1.287405
# 10     1.224755     1.238409     1.262493     1.272277     1.289548
# 11     1.236881     1.252961     1.268144     1.288349     1.303091
# 12     1.242923     1.271185     1.284266     1.316014     1.231520
# 13     1.216346     1.243973     1.265293     1.283287     1.257243
# 14     1.162515     1.196462     1.221030     1.245689     1.255820
# 15     1.147547     1.173971     1.213914     1.239907     1.263985
# 16     1.247899     1.253355     1.274886     1.295021     1.300102
# 17     1.225224     1.241605     1.251055     1.276291     1.257590
# 18     1.209117     1.232265     1.255110     1.267071     1.271932
# 19     1.187329     1.216092     1.239588     1.259853     1.281106
# 20     1.192654     1.222480     1.247473     1.265223     1.279126
# 21     1.224277     1.250597     1.262213     1.286013     1.225083
# 22     1.223688     1.251757     1.271028     1.299461     1.233623
# 23     1.207357     1.237480     1.250352     1.273242     1.212260
# 24     1.220556     1.241747     1.260483     1.274427     1.227429
# 25     1.216910     1.240362     1.258414     1.278576     1.250313
# 26     1.223657     1.243059     1.268803     1.279535     1.292552
# 27     1.203405     1.229612     1.244302     1.267760     1.277744
# 28     1.214108     1.236832     1.264889     1.278272     1.288166
# 29     1.214645     1.232480     1.250810     1.269168     1.284636
# 30     1.227048     1.249672     1.267421     1.284605     1.304134
# 31     1.222856     1.242992     1.264961     1.278480     1.291149
# 32     1.193676     1.215842     1.248764     1.270184     1.282696
# 33     1.185219     1.216441     1.240234     1.261010     1.276013
# 34     1.191344     1.217995     1.242712     1.265151     1.273448
# 35     1.199079     1.230152     1.255975     1.271034     1.287976
# 36     1.223582     1.253362     1.270257     1.286046     1.222422
# 37     1.225558     1.255617     1.278059     1.289276     1.304098
# 38     1.255432     1.259085     1.283364     1.290963     1.303616
# 39     1.213603     1.228284     1.252362     1.284587     1.299535
# 40     1.242758     1.242135     1.267099     1.291053     1.302889
# 41     1.268445     1.291689     1.289337     1.307472     1.249372
# 42     1.236775     1.250118     1.267737     1.281177     1.258787
# 43     1.261425     1.263564     1.274996     1.292608     1.305140
# 44     1.224243     1.231407     1.255565     1.285385     1.300601
# 45     1.245309     1.244297     1.270138     1.284427     1.295979
# 46     1.242566     1.278722     1.269426     1.288154     1.295843
# 47     1.253407     1.283604     1.271473     1.287577     1.313725
# 48     1.213938     1.249290     1.244735     1.267019     1.273849
# 49     1.258589     1.293267     1.280068     1.289178     1.307505
# 50     1.243103     1.274070     1.269862     1.281093     1.287953
# 51     1.222295     1.238942     1.245682     1.191846     1.198974
# 52     1.238705     1.261821     1.289389     1.218379     1.212102
# 53     1.212914     1.228477     1.242877     1.190009     1.196491
# 54     1.201926     1.162770     1.173205     1.162726     1.168570
# 55     1.202795     1.229580     1.170451     1.189367     1.173706
# 56     1.223194     1.247032     1.300765     1.207600     1.231914
# 57     1.193289     1.209944     1.175943     1.159782     1.184718
# 58     1.222375     1.238392     1.252411     1.195963     1.210064
# 59     1.237687     1.246042     1.253986     1.211382     1.203032
# 60     1.228345     1.237367     1.203006     1.200348     1.209557
#
#     NIR.1694 nm  NIR.1696 nm  NIR.1698 nm  NIR.1700 nm
# 1      1.264189     1.244678     1.245913     1.221135
# 2      1.215065     1.225211     1.227985     1.198851
# 3      1.218871     1.223132     1.230321     1.208742
# 4      1.211068     1.215044     1.232655     1.206696
# 5      1.226448     1.230718     1.232864     1.202926
# 6      1.229769     1.227615     1.227630     1.207576
# 7      1.218317     1.218147     1.222273     1.200446
# 8      1.221264     1.220265     1.227947     1.188174
# 9      1.211995     1.213263     1.215883     1.196102
# 10     1.213103     1.212666     1.216313     1.192221
# 11     1.220515     1.218996     1.218947     1.196750
# 12     1.242926     1.245499     1.218605     1.222376
# 13     1.241994     1.245265     1.221914     1.227010
# 14     1.195502     1.201374     1.217044     1.190482
# 15     1.236485     1.213466     1.222574     1.194232
# 16     1.272523     1.237184     1.253393     1.225255
# 17     1.211339     1.224403     1.196473     1.206524
# 18     1.208274     1.202633     1.220311     1.192021
# 19     1.213803     1.216212     1.212221     1.187919
# 20     1.215044     1.215047     1.224300     1.195850
# 21     1.224663     1.233307     1.198024     1.208770
# 22     1.238265     1.239621     1.216958     1.215150
# 23     1.227581     1.228188     1.200708     1.208866
# 24     1.232069     1.232610     1.203415     1.206482
# 25     1.225191     1.234871     1.202831     1.200294
# 26     1.223150     1.230409     1.234873     1.199130
# 27     1.209736     1.214851     1.218626     1.185845
# 28     1.220597     1.222195     1.237040     1.198483
# 29     1.221910     1.220088     1.225551     1.190114
# 30     1.228024     1.230893     1.224984     1.209100
# 31     1.223628     1.232818     1.223925     1.203394
# 32     1.219395     1.230635     1.218142     1.198047
# 33     1.210541     1.219328     1.221799     1.188120
# 34     1.216081     1.219200     1.223790     1.200368
# 35     1.222506     1.232113     1.233227     1.215170
# 36     1.236444     1.226974     1.207932     1.208693
# 37     1.228055     1.248893     1.238919     1.219423
# 38     1.299003     1.247123     1.242375     1.253576
# 39     1.308261     1.240087     1.237938     1.249060
# 40     1.311104     1.242112     1.247460     1.241335
# 41     1.245525     1.247599     1.228605     1.225721
# 42     1.230622     1.229405     1.232895     1.204329
# 43     1.279795     1.254112     1.249215     1.221268
# 44     1.288432     1.243036     1.241742     1.239797
# 45     1.228903     1.236879     1.236562     1.200461
# 46     1.296007     1.234071     1.244711     1.239300
# 47     1.316089     1.324185     1.251984     1.254192
# 48     1.284502     1.297106     1.226739     1.219197
# 49     1.312363     1.290606     1.246904     1.244676
# 50     1.297078     1.301496     1.237601     1.227748
# 51     1.180956     1.176291     1.152654     1.170770
# 52     1.235187     1.215633     1.222602     1.183570
# 53     1.198856     1.165040     1.189147     1.150035
# 54     1.148061     1.167755     1.137953     1.145351
# 55     1.198534     1.162526     1.195273     1.156451
# 56     1.245133     1.230234     1.264217     1.190865
# 57     1.155629     1.175611     1.117087     1.095777
# 58     1.199746     1.173102     1.191871     1.150779
# 59     1.209177     1.183871     1.175997     1.154696
# 60     1.182911     1.184077     1.154355     1.163959
#
# [60 rows x 401 columns]

# %%
print(ydata.shape)
ydata.head()
# Out:
# (60,)
# 1    85.30
# 2    85.25
# 3    88.45
# 4    83.40
# 5    87.90
# Name: octane, dtype: float64

# %% [markdown]
# # Calculate the derivatives

# %%
from scipy.signal import savgol_filter

# Calculate derivatives
xdata1 = savgol_filter(xdata, 10, polyorder = 2, deriv=1)
xdata2 = savgol_filter(xdata, 10, polyorder = 2, deriv=2)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

fig, ax = plt.subplots(figsize=(20, 8))
ax.plot(wls, xdata.values.T, linewidth=0.5)
ax.set_title('NIR spectra of %s samples' % dataset)
ax.set_xlabel('wavelength [nm]')
ax.set_ylabel('log(1/R)')

plt.grid()
plt.savefig('octane_101.png')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

fig, ax = plt.subplots(figsize=(20, 8))
ax.plot(wls, xdata1.T, linewidth=0.5)
ax.set_title('NIR spectra of %s samples' % dataset)
ax.set_xlabel('wavelength [nm]')
ax.set_ylabel('First derivative log(1/R)')

plt.grid()
plt.savefig('octane_102.png')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

fig, ax = plt.subplots(figsize=(20, 8))
ax.plot(wls, xdata2.T, linewidth=0.5)
ax.set_title('NIR spectra of %s samples' % dataset)
ax.set_xlabel('wavelength [nm]')
ax.set_ylabel('Second derivative log(1/R)')

plt.grid()
plt.savefig('octane_103.png')
plt.show()

# %%
from sklearn.model_selection import train_test_split
 
X_train, X_test, y_train, y_test = train_test_split(xdata, ydata, test_size=0.16, shuffle=False)

# %% [markdown]
# # Partial Least Squares Regression

# %%
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_error
 
list_mse = []
n_comp = int(xdata.shape[1] / 10)
component = np.arange(1, n_comp + 1)
     
for i in component:
    pls = PLSRegression(n_components=i)
 
    # Cross-validation
    y_cv = cross_val_predict(pls, X_train, y_train, cv=10)
    # Root Mean Square Error of Precision
    mse = mean_squared_error(y_train, y_cv, squared=True)
    list_mse.append(mse)
 
# Calculate and print the position of minimum in MSE
mse_min = np.argmin(list_mse)
print('Suggested number of components: ', mse_min + 1)
# Out:
# Suggested number of components:  4

# %%
# Define PLS object with optimal number of components
pls_opt = PLSRegression(n_components=mse_min + 1)

# Fit to the entire dataset
pls_opt.fit(X_train, y_train)
# Out:
# PLSRegression(n_components=4)

# %% [markdown]
# # NIR variable selection for PLS regression

# %%
from sys import stdout
import warnings

warnings.simplefilter("ignore")
X = xdata.values
y = ydata
max_comp=40

# Define MSE array to be populated
mse = np.zeros((max_comp, X.shape[1]))

# Loop over the number of PLS components
for i in range(max_comp):
    
    # Regression with specified number of components, using full spectrum
    pls1 = PLSRegression(n_components=i + 1)
    pls1.fit(X, y)
    
    # Indices of sort spectra according to ascending absolute value of PLS coefficients
    sorted_ind = np.argsort(np.abs(pls1.coef_[:,0]))

    # Sort spectra accordingly 
    Xc = X[:, sorted_ind]

    # Discard one wavelength at a time of the sorted spectra,
    # regress, and calculate the MSE cross-validation
    for j in range(Xc.shape[1] - (i + 1)):

        pls2 = PLSRegression(n_components=i + 1)
        pls2.fit(Xc[:, j:], y)
        
        y_cv = cross_val_predict(pls2, Xc[:, j:], y, cv=5)

        mse[i,j] = mean_squared_error(y, y_cv)

    comp = 100 * (i + 1) / (max_comp)
    stdout.write("\r%d%% completed" % comp)
    stdout.flush()
stdout.write("\n")

# Calculate and print the position of minimum in MSE
mseminx,mseminy = np.where(mse==np.min(mse[np.nonzero(mse)]))

print("Optimised number of PLS components: ", mseminx[0] + 1)
print("Wavelengths to be discarded ", mseminy[0])
print('Optimised MSEP ', mse[mseminx,mseminy][0])
stdout.write("\n")
# plt.imshow(mse, interpolation=None)
# plt.show()


# Calculate PLS with optimal components and export values
pls = PLSRegression(n_components=mseminx[0] + 1)
pls.fit(X, y)
    
sorted_ind = np.argsort(np.abs(pls.coef_[:, 0]))

Xc = X[:,sorted_ind]
opt_Xc = Xc[:, mseminy[0]:]

ncomp = mseminx[0] + 1
wav = mseminy[0]
# Out:
# 100% completed
# Optimised number of PLS components:  18
# Wavelengths to be discarded  317
# Optimised MSEP  0.014025143902352521
