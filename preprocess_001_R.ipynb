# %%
x = c(1:1000)

# %%
r = rnorm(800, mean=0, sd=1)

# %%
y = c(rep(0, times=100), 100 + r, rep(0, times=100))

# %%
plot(x, y, type="l")
# Out:
# plot without title

# %%
y1 = c(rep(0, times=100), 5 + r, rep(0, times=100))

# %%
plot(x, y1, type="l")
# Out:
# plot without title

# %%
png("plot_001.png")
plot(x, y, type="l")
dev.off()
# Out:
# png
#   2

# %%
png("plot_002.png")
plot(x, y1, type="l")
dev.off()
# Out:
# png
#   2
